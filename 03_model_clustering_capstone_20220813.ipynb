# %% [markdown]
# # Capstone Project: KMeans Model <br>
#
# #### Brandie Hatch
#
# ### Modeling
#
# - Imports, Data Reading, Model Prep
# - Modeling
# - Model Evaluation
#
# #### Performing two types of models:
# 1. Clustering / k-Means to see if there are any interesting patterns in the data
# 2. Supervised Classification - likely a combination of Logistic Regression, KNN Classifier, Random Forest, Decision Trees, Naive Bayes, and SVM to see which one performs the best at accurately predicting male or female based on education attainment, labor types, income, etc.

# %% [markdown]
# ## Imports, Data Reading, and Model Prep

# %%
# python library imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

matplotlib.style.use('ggplot')

from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %matplotlib inline
pd.options.display.max_columns =999

# %%
# Read in Data

df = pd.read_csv('./data/data_clean.csv', index_col=False)
print(df.shape)
df.head()
# Out:
# (3239553, 26)
#    AGEP  CIT  COW  ENG  ESR  FFSP  LANX  MAR  MULTG  NOC  OCCP  PINCP  POVPIP  \
# 0    35    1    1    0    6     0     2    1      0   -1  6250  63000      -1
# 1    25    1    0    0    6     0     2    5      0   -1     9      0      -1
# 2    21    5    2    0    1     0     2    5      0   -1  4740   2000      -1
# 3    49    1    1    0    6     0     2    3      0   -1   110      0      -1
# 4    18    1    1    0    6     0     2    5      0   -1  4110   6000      -1
#
#    RAC1P  SCH  SCHG  SCHL  SCIENGP  SCIENGRLP  SEMP  SEX   WAGP  WKEXREL  WKL  \
# 0      1    1     0    17        0          0     0    1  63000        0    1
# 1      1    1     0    12        0          0     0    1      0        0    3
# 2      6    3    15    19        0          0     0    2   2000        0    1
# 3      1    1     0    21        1          2     0    1      0        0    2
# 4      1    2    15    16        0          0     0    2   6000        0    1
#
#    WRK  STATE
# 0    0     18
# 1    0     48
# 2    0     18
# 3    0      4
# 4    2      6

# %%
df = df.sample(n=10000, replace=False, axis=0, ignore_index=True, random_state=42)
print(df.shape)
df.head()
# Out:
# (10000, 26)
#    AGEP  CIT  COW  ENG  ESR  FFSP  LANX  MAR  MULTG  NOC  OCCP  PINCP  POVPIP  \
# 0    49    1    0    0    6     0     2    3      1    2     9  27800     136
# 1    70    1    0    0    6     0     2    2      1    0     9  38000     442
# 2    58    1    1    0    1     0     2    1      1    0   410  89000     501
# 3    76    1    0    0    6     0     2    2      1    0     9  96400     501
# 4    57    1    0    0    6     0     2    3      1    0     9   9700      73
#
#    RAC1P  SCH  SCHG  SCHL  SCIENGP  SCIENGRLP  SEMP  SEX   WAGP  WKEXREL  WKL  \
# 0      1    1     0    19        0          0     0    1      0       12    3
# 1      1    1     0    13        0          0     0    1      0       12    3
# 2      1    1     0    16        0          0     0    1  89000        1    1
# 3      1    1     0    21        2          2     0    1      0        0    3
# 4      1    1     0    16        0          0     0    1      0        0    3
#
#    WRK  STATE
# 0    2     26
# 1    2     42
# 2    1     36
# 3    2     17
# 4    2     39

# %%
# Prepare X matrix

X = df[['AGEP', 'PINCP']]
sc = StandardScaler()
X_sc = sc.fit_transform(X)

# %%
# Fit a k-means clustering model

km = KMeans(init='random', n_clusters=5, n_init=5, max_iter=100, random_state=42)
km.fit(X_sc)
# Out:
# KMeans(init='random', max_iter=100, n_clusters=5, n_init=5, random_state=42)

# %%
# Look at Centroids

km.cluster_centers_
# Out:
# array([[-1.27841954, -0.73169702],
#        [-0.21389097, -0.04268334],
#        [ 0.53829209,  5.98191408],
#        [ 0.42695932,  1.44542703],
#        [ 1.08913244, -0.10230753]])

# %%
# Class attribute

km.labels_
# Out:
# array([1, 4, 3, ..., 0, 3, 4])

# %%
km.predict(X_sc)
# Out:
# array([1, 4, 3, ..., 0, 3, 4])

# %%
# attach predicted cluster to original points
df['cluster'] = km.labels_
df
# Out:
#       AGEP  CIT  COW  ENG  ESR  FFSP  LANX  MAR  MULTG  NOC  OCCP  PINCP  \
# 0       49    1    0    0    6     0     2    3      1    2     9  27800
# 1       70    1    0    0    6     0     2    2      1    0     9  38000
# 2       58    1    1    0    1     0     2    1      1    0   410  89000
# 3       76    1    0    0    6     0     2    2      1    0     9  96400
# 4       57    1    0    0    6     0     2    3      1    0     9   9700
# ...    ...  ...  ...  ...  ...   ...   ...  ...    ...  ...   ...    ...
# 9995    29    1    1    0    1     0     2    5      1    0  4760  18000
# 9996    16    1    0    1    6     0     1    5      1    3     9      0
# 9997    19    1    9    0    3     0     2    5      1    0  9920      0
# 9998    50    1    1    0    1     0     2    2      1    0  9130  85000
# 9999    80    1    0    0    6     0     2    3      1    0     9  28800
#
#       POVPIP  RAC1P  SCH  SCHG  SCHL  SCIENGP  SCIENGRLP  SEMP  SEX   WAGP  \
# 0        136      1    1     0    19        0          0     0    1      0
# 1        442      1    1     0    13        0          0     0    1      0
# 2        501      1    1     0    16        0          0     0    1  89000
# 3        501      1    1     0    21        2          2     0    1      0
# 4         73      1    1     0    16        0          0     0    1      0
# ...      ...    ...  ...   ...   ...      ...        ...   ...  ...    ...
# 9995     373      1    1     0    16        0          0     0    1  18000
# 9996     135      2    2    12    13        0          0     0    2      0
# 9997     224      9    1     0    14        0          0     0    2      0
# 9998     501      1    1     0    16        0          0     0    1  85000
# 9999     237      1    1     0    16        0          0     0    1      0
#
#       WKEXREL  WKL  WRK  STATE  cluster
# 0          12    3    2     26        1
# 1          12    3    2     42        4
# 2           1    1    1     36        3
# 3           0    3    2     17        3
# 4           0    3    2     39        4
# ...       ...  ...  ...    ...      ...
# 9995        2    1    1      8        1
# 9996       14    3    0     34        0
# 9997       13    3    2     53        0
# 9998       10    1    1     27        3
# 9999        0    3    2     48        4
#
# [10000 rows x 27 columns]

# %%
# Show mean values for x1 and x2 WITHIN EACH CLUSTER for data
df.groupby('cluster').mean()
# Out:
#               AGEP       CIT       COW       ENG       ESR      FFSP  \
# cluster
# 0        12.166667  1.184429  0.433862  0.203326  1.324641  0.027211
# 1        37.316586  1.625602  1.760496  0.362698  2.031315  0.019959
# 2        55.150000  1.475000  2.416667  0.150000  1.975000  0.008333
# 3        52.516464  1.474870  2.030329  0.192374  1.598787  0.012998
# 4        68.151229  1.436358  1.230309  0.266226  4.329868  0.024260
#
#              LANX       MAR     MULTG       NOC         OCCP          PINCP  \
# cluster
# 0        1.471277  4.897581  1.039683  1.605442  1254.007181  -10222.663643
# 1        1.776669  2.736407  1.049209  0.777357  3933.404680   32242.408809
# 2        1.875000  1.608333  1.008333  0.875000  2178.908333  403734.833333
# 3        1.846620  1.694974  1.038995  0.584055  2638.121317  124028.032929
# 4        1.862634  1.825457  1.018589  0.023945  2273.839319   28622.436988
#
#              POVPIP     RAC1P       SCH      SCHG       SCHL   SCIENGP  \
# cluster
# 0        270.237339  2.193500  1.752834  6.518896   9.236206  0.037415
# 1        305.316586  2.075361  1.091879  1.112526  18.243290  0.516518
# 2        496.816667  1.408333  1.016667  0.100000  20.491667  1.025000
# 3        492.454939  1.698440  1.031196  0.353553  20.349220  0.978336
# 4        311.400126  1.559861  1.013863  0.160681  17.584751  0.402962
#
#          SCIENGRLP          SEMP       SEX           WAGP   WKEXREL       WKL  \
# cluster
# 0         0.047997  -5953.130008  1.492819    1531.972033  5.403628  0.626228
# 1         0.604267   1253.334480  1.517550   29660.385409  4.502065  1.275637
# 2         1.408333  51908.416667  1.250000  253253.333333  3.383333  1.266667
# 3         1.181109   4884.454073  1.358752   96993.223570  3.298960  1.162912
# 4         0.450851    904.269061  1.566163   10563.919345  5.164776  2.140832
#
#               WRK      STATE
# cluster
# 0        0.473923  27.903250
# 1        1.071232  28.048176
# 2        1.100000  25.208333
# 3        1.064991  26.392548
# 4        1.485192  27.752363

# %%
km.cluster_centers_
# Out:
# array([[-1.27841954, -0.73169702],
#        [-0.21389097, -0.04268334],
#        [ 0.53829209,  5.98191408],
#        [ 0.42695932,  1.44542703],
#        [ 1.08913244, -0.10230753]])

# %%
# silohuet score
# and plot - look for the elbow in the plot

# %%
## Create a dataframe for cluster_centers (centroids)

centroids = pd.DataFrame(
    sc.inverse_transform(km.cluster_centers_),
    columns=["SCHL", "PINCP"]
)

centroids.head()

# from James - - age, schl, income distance along age axis
# Out:
#         SCHL          PINCP
# 0  12.176360  -10207.200906
# 1  37.357388   32275.408935
# 2  55.150000  403734.833333
# 3  52.516464  124028.032929
# 4  68.179924   28599.152462

# %%
plt.figure(figsize=(7,7));

## Plot scatter by cluster / color, and centroids

colors = ["red", "green", "blue", "purple", "orange"]
df['color'] = df['cluster'].map(lambda p: colors[p])
ax = df.plot(    
    kind="scatter", 
    x="AGEP", y="PINCP",
    figsize=(10,8),
    c = df['color']
)

centroids.plot(
    kind="scatter", 
    x="AGEP", y="PINCP", 
    marker="*", c=["r", "g", "b", 'p', 'o'], s=550,
    ax=ax
);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\hatch\anaconda3\envs\dsi-222\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# c:\Users\hatch\anaconda3\envs\dsi-222\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\hatch\anaconda3\envs\dsi-222\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AGEP'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13448/2682456384.py in <module>
#      12 )
#      13
# ---> 14 centroids.plot(
#      15     kind="scatter",
#      16     x="AGEP", y="PINCP",
#
# c:\Users\hatch\anaconda3\envs\dsi-222\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     915         if kind in self._dataframe_kinds:
#     916             if isinstance(data, ABCDataFrame):
# --> 917                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918             else:
#     919                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# c:\Users\hatch\anaconda3\envs\dsi-222\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# c:\Users\hatch\anaconda3\envs\dsi-222\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     327         self._compute_plot_data()
#     328         self._setup_subplots()
# --> 329         self._make_plot()
#     330         self._add_table()
#     331         self._make_legend()
#
# c:\Users\hatch\anaconda3\envs\dsi-222\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1113             label = None
#    1114         scatter = ax.scatter(
# -> 1115             data[x].values,
#    1116             data[y].values,
#    1117             c=c_values,
#
# c:\Users\hatch\anaconda3\envs\dsi-222\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# c:\Users\hatch\anaconda3\envs\dsi-222\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'AGEP'

# %% [markdown]
# ## Modeling

# %%
silhouette_score(X_sc, km.labels_)
# Out:
# 0.5854670290172024

# %%
scores = []
for k in range(2, 31):
    km = KMeans(n_clusters=k)
    km.fit(X_sc)
    inertia = km.inertia_
    sil = silhouette_score(X_sc, km.labels_)
    scores.append([k, inertia, sil])
    
score_df = pd.DataFrame(scores)
score_df.columns = ['k', 'inertia', 'silhouette']
score_df.head()
# Out:
#    k       inertia  silhouette
# 0  2  10942.588219    0.562218
# 1  3   6272.100028    0.585396
# 2  4   4089.995845    0.495197
# 3  5   3057.417238    0.436094
# 4  6   2446.870208    0.439261

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 7))

axes[0].plot(score_df['k'], score_df['inertia'])
axes[0].set_title('Inertia Over k')

axes[1].plot(score_df['k'], score_df['silhouette'])
axes[1].set_title('Silhouette Over k')
# Out:
# Text(0.5, 1.0, 'Silhouette Over k')

# %% [markdown]
# The elbow of the plot is around 5, so I will run the model with a K of 5 to see if I get better results.

# %% [markdown]
# ### Findings

# %% [markdown]
# ### Recommendations

# %% [markdown]
# ## Sources
